# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

# %%
def generar_gantt(tareas, titulo="Diagrama de Gantt"):
    """
    Genera un diagrama de Gantt a partir de una lista de tareas.

    Parámetros:
    - tareas: lista de diccionarios con claves: 'nombre', 'inicio', 'fin'.
              Ejemplo: [
                  {"nombre": "Fase 1", "inicio": "2024-06-01", "fin": "2024-06-10"},
                  {"nombre": "Fase 2", "inicio": "2024-06-11", "fin": "2024-06-20"},
              ]
    - titulo: título del gráfico
    """
    df = pd.DataFrame(tareas)
    df = df.iloc[::-1].reset_index(drop=True) # reverse orders
    df["inicio"] = pd.to_datetime(df["inicio"])
    df["fin"] = pd.to_datetime(df["fin"])
    df["duracion"] = df["fin"] - df["inicio"]

    fig, ax = plt.subplots(figsize=(10, 6))
    for i, tarea in df.iterrows():
        ax.barh(tarea["nombre"], tarea["duracion"].days,
                left=tarea["inicio"], height=0.5, color="skyblue", edgecolor="black")

    ax.set_xlabel("Fecha")
    ax.set_ylabel("Tareas")
    ax.set_title(titulo)
    ax.xaxis_date()
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%d-%b"))

    plt.tight_layout()
    plt.grid(True, axis='x', linestyle='--', alpha=0.5)
    plt.show()

# %%
tareas = [
    {"nombre": "Investigación sobre UWB Estimote Beacons", "inicio": "2025-02-26", "fin": "2025-03-02"},
    {"nombre": "Conexión a UWB Estimote Beacons", "inicio": "2025-03-05", "fin": "2025-03-12"},
    {"nombre": "Demostración en la UVG con QR", "inicio": "2025-03-12", "fin": "2025-03-12"},
    {"nombre": "Reunión con antecesor del proyecto", "inicio": "2025-03-22", "fin": "2025-03-22"},
    {"nombre": "Investigación sobre Unity Plugins", "inicio": "2025-03-26", "fin": "2025-03-28"},
    {"nombre": "Prueba de concepto con plugins", "inicio": "2025-03-29", "fin": "2025-04-09"},
    {"nombre": "Conexión de múltiples sensores UWB via SDK", "inicio": "2025-04-23", "fin": "2025-04-30"},
    {"nombre": "Integración Estimote SDK + Unity", "inicio": "2025-05-01", "fin": "2025-05-14"},
    {"nombre": "Desarrollo del MVP", "inicio": "2025-05-14", "fin": "2025-05-30"},

    {"nombre": "Pruebas iniciales de trilateración con sensores UWB", "inicio": "2025-06-09", "fin": "2025-06-15"},
    {"nombre": "Investigación sobre filtros de Kalman", "inicio": "2025-06-16", "fin": "2025-06-22"},
    {"nombre": "Desarrollo del modelo matemático de Kalman e implementación inicial", "inicio": "2025-06-23", "fin": "2025-06-29"},
    {"nombre": "Ajustes del modelo de filtrado Kalman (fine tuning)", "inicio": "2025-06-30", "fin": "2025-07-06"},
    {"nombre": "Redacción del protocolo y refactorización del plugin en Swift", "inicio": "2025-07-07", "fin": "2025-07-13"},
    {"nombre": "Finalización de arquitectura del plugin y conexión con sensores UWB", "inicio": "2025-07-14", "fin": "2025-07-20"},
    {"nombre": "Implementación del algoritmo de trilateración en el plugin", "inicio": "2025-07-21", "fin": "2025-07-27"},
    {"nombre": "Integración del filtro de Kalman con posiciones del plugin", "inicio": "2025-07-28", "fin": "2025-08-03"},
    {"nombre": "Transmisión de posición a Unity y validación con AR Foundation", "inicio": "2025-08-04", "fin": "2025-08-10"},
    {"nombre": "Pruebas de localización en movimiento dentro de Unity", "inicio": "2025-08-11", "fin": "2025-08-17"},
    {"nombre": "Pruebas integradas en un piso del CIT (pre-MVP)", "inicio": "2025-08-18", "fin": "2025-08-24"},
    {"nombre": "Entrega del MVP: App funcional en al menos un piso del CIT", "inicio": "2025-08-25", "fin": "2025-08-31"},
    {"nombre": "Evaluación cualitativa de precisión y suavidad del sistema", "inicio": "2025-09-01", "fin": "2025-09-07"},
    {"nombre": "Análisis de datos: trayectorias, ruido, offset", "inicio": "2025-09-08", "fin": "2025-09-14"},
    {"nombre": "Documentación técnica del sistema y estructura del código", "inicio": "2025-09-15", "fin": "2025-09-21"},
    {"nombre": "Redacción de guía técnica para futuras generaciones", "inicio": "2025-09-22", "fin": "2025-09-28"},
    {"nombre": "Pruebas finales y preparación de entrega formal", "inicio": "2025-09-29", "fin": "2025-10-05"}
]

generar_gantt(tareas, titulo="Cronograma de Proyecto AR con UWB")
